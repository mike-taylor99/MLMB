# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import re
import os
# Out:
# C:\Users\mtayl\AppData\Local\Temp\ipykernel_13084\3683021745.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# ## Create initial dataframe
# We will create an initial dataframe with the name of the school and City, State from the list of men's college basketball schools as listed on sportsreference

# %%
url = 'https://www.sports-reference.com/cbb/schools/'
html = requests.get(url).content

df_list = pd.read_html(html)
df = df_list[0] # first table is men's, second is women's

# drop repeating header rows from table
df.drop_duplicates(keep=False, inplace=True)

df = df.loc[:, ['School', 'City, State']]

# %% [markdown]
# ## Add SR key
# We will parse the urls for each of the schools listed on sportsreference and add the key to our dataframe

# %%
# create a BeautifulSoup object
soup = BeautifulSoup(html, 'html.parser')

# find the table element
table = soup.find('table')

# find all rows in the table
rows = table.find_all('tr')

for row in rows[1:]:
    try:
        # extract the hyperlink
        link = row.find_all('td')[0].find('a')
        if link:
            # create a BeautifulSoup object
            soup = BeautifulSoup(str(link), 'html.parser')

            # extract the text and hyperlink
            text = soup.get_text().strip()
            link = soup.a['href']

            # extract the school name from the hyperlink using regex
            key = re.search(r'/schools/(.*)/men', link).group(1)

            df.loc[df['School'] == text, 'SR key'] = key
    except IndexError:
        pass

# %% [markdown]
# ## Add NCAA key
# We will parse the schools listed in the NCAA website and add the key to our dataframe

# %%
hardcoded_schools_dict = {
    "Augusta State Jaguars": "", # Does not exist on NCAA website
    "Baker University Wildcats": "", # Does not exist on NCAA website
    "Baltimore Super Bees": "", # Does not exist on NCAA website
    "Birmingham-Southern Panthers": "birmingham-so",
    "Boston University": "boston-u",
    "Brigham Young College": "", # Does not exist on NCAA website
    "Cal State Bakersfield": "bakersfield",
    "Cal State Fullerton": "cal-st-fullerton",
    "Cal State Los Angeles Golden Eagles": "cal-st-la",
    "Cal State Northridge": "cal-st-northridge",
    "Canterbury College": "", # Does not exist on NCAA website
    "Carleton College Knights": "carleton",
    "Case Western Reserve Spartans": "case",
    "Central Missouri Mules": "central-mo",
    "Central Pennsylvania College Knights": "", # Does not exist on NCAA website
    "Centre (KY) Colonels": "centre",
    "Cheyenne Business College": "", # Does not exist on NCAA website
    "City College of New York Beavers": "ccny",
    "College of New Jersey Lions": "tcnj",
    "Colorado College Tigers": "colorado-col",
    "Colorado School of Mines Orediggers": "colorado-mines",
    "Concordia Seminary Preachers": "", # Does not exist on NCAA website
    "Cotner College": "", # Does not exist on NCAA website
    "Cumberland": "", # Does not exist on NCAA website
    "Dakota Wesleyan Tigers": "", # Does not exist on NCAA website
    "Dickinson College Red Devils": "dickinson",
    "Emporia State Hornets": "emporia-st",
    "Ensign College": "", # Does not exist on NCAA website
    "Haskell (KS) Fighting Indians": "", # Does not exist on NCAA website
    "Illinois Wesleyan Titans": "ill-wesleyan",
    "Kentucky Wesleyan Panthers": "ky-wesleyan",
    "Lawrence Tech": "", # Does not exist on NCAA website
    "Long Island University": "long-island",
    "Louisiana": "la-lafayette",
    "Louisiana-Monroe": "la-monroe",
    "Loyola (LA) Wolfpack": "", # Does not exist on NCAA website
    "Loyola (MD)": "loyola-maryland",
    "Maryland-Baltimore County": "umbc",
    "Maryland-Eastern Shore": "umes",
    "Massachusetts Institute of Technology Engineers": "mit",
    "Massachusetts-Lowell": "umass-lowell",
    "Merchant Marine Mariners": "merchant-marine",
    "Middle Tennessee": "middle-tenn",
    "Minnesota A&M Aggies": "", # Does not exist on NCAA website
    "Montana State": "montana-st",
    "NC State": "north-carolina-st",
    "Nebraska Wesleyan Prairie Wolves": "neb-wesleyan",
    "Nevada-Las Vegas": "unlv",
    "New York University Violets": "new-york-u",
    "North Central Cardinals": "north-central-il",
    "Northeastern Illinois Golden Eagles": "northeastern-ill",
    "Northwest Missouri State Bearcats": "northwest-mo-st",
    "Ohio State": "ohio-st",
    "Oklahoma City Chiefs": "", # Does not exist on NCAA website
    "Phillips Haymakers": "", # Does not exist on NCAA website
    "Pittsburg State Gorillas": "pittsburg-st",
    "Saint Francis (PA)": "saint-francis-pa",
    "Saint Mary's (CA)": "st-marys-ca",
    "Sam Houston": "sam-houston-st",
    "Savage School of Physical Education": "", # Does not exist on NCAA website
    "Savannah State Tigers": "savannah-st",
    "Southern Illinois-Edwardsville": "siu-edwardsville",
    "Southern Mississippi": "southern-miss",
    "Southwestern (KS) Moundbuilders": "", # Does not exist on NCAA website
    "St. John's College (OH)": "", # Does not exist on NCAA website
    "Stevens Institute Ducks": "stevens",
    "Tennessee-Martin": "ut-martin",
    "Texas-Rio Grande Valley": "utrgv",
    "U.S. International Gulls": "", # Does not exist on NCAA website
    "UTEP": "utep",
    "UTSA": "utsa",
    "Washington & Jefferson Presidents": "wash-jeff",
    "Washington & Lee Generals": "wash-lee",
    "Washington (MO) Bears": "", # Does not exist on NCAA website
    "Washington College Shoremen": "washington-col",
    "Wayne State (MI) Warriors": "wayne-st-mi",
    "West Texas A&M Buffaloes": "west-tex-am",
    "Western Colorado Mountaineers": "western-st",
    "Wisconsin-Stevens Point Pointers": "wis-stevens-point",
    "Wisconsin-Superior Yellowjackets": "wis-superior",
    "WPI Engineers": "wpi"
}

# %%
for school in hardcoded_schools_dict:
    df.loc[df['School'] == school, 'NCAA key'] = hardcoded_schools_dict[school]

# %%
ncaa_url = 'https://www.ncaa.com/schools-index/'
MAX_SCHOOLS_INDEX = 23

for i in range(0, MAX_SCHOOLS_INDEX + 1):
    html = requests.get(f'{ncaa_url}{i}').content

    # create a BeautifulSoup object
    soup = BeautifulSoup(html, 'html.parser')

    # find the table element
    table = soup.find('table')

    # find all rows in the table
    rows = table.find_all('tr')

    for row in rows[1:]:
        try:
            # extract the hyperlink
            link = row.find_all('td')[1].find('a')
            if link:
                # create a BeautifulSoup object
                soup = BeautifulSoup(str(link), 'html.parser')

                # extract the text and hyperlink
                text = soup.get_text().strip()
                link = soup.a['href']

                # extract the full name
                full_name = row.find_all('td')[2].get_text().strip()

                parsed_name = re.sub(r"\bUniversity(?: of)?\b", "", full_name)
                parsed_name = full_name.replace('  ', '').strip()
                print(full_name, parsed_name)

                # extract the school name from the hyperlink using regex
                key = re.search(r'/schools/(.*)', link).group(1)
                
                row = df.loc[(df['School'] == text) | (df['SR key'] == key) | (df['School'] == parsed_name)]
                if not row.empty:
                    df.loc[(df['School'] == text) | (df['SR key'] == key) | (df['School'] == parsed_name), 'NCAA key'] = key
        except IndexError:
            pass

# %%
import json

print(f"Total schools: {len(df)}")
print(f"No. of schools where NCAA key is NaN (we didn't add to hardcoded values or found in automation) {len(df.loc[df['NCAA key'].isnull()])}")
schools = df.loc[df['NCAA key'].duplicated()]
for index, row in schools.iterrows():
    dict = row.to_dict()
    print(f"Duplicated NCAA Key or not found in NCAA {dict}")
# Out:
# Total schools: 491
# No. of schools where NCAA key is NaN (we didn't add to hardcoded values or found in automation) 93
# Duplicated NCAA Key or not found in NCAA {'School': 'Alcorn State', 'City, State': 'Alcorn State, Mississippi', 'SR key': 'alcorn-state', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Appalachian State', 'City, State': 'Boone, North Carolina', 'SR key': 'appalachian-state', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Arizona State', 'City, State': 'Tempe, Arizona', 'SR key': 'arizona-state', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Arkansas State', 'City, State': 'State University, Arkansas', 'SR key': 'arkansas-state', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Arkansas-Pine Bluff', 'City, State': 'Pine Bluff, Arkansas', 'SR key': 'arkansas-pine-bluff', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Baker University Wildcats', 'City, State': 'Baldwin City, Kansas', 'SR key': 'baker-university', 'NCAA key': ''}
# Duplicated NCAA Key or not found in NCAA {'School': 'Ball State', 'City, State': 'Muncie, Indiana', 'SR key': 'ball-state', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Baltimore Super Bees', 'City, State': 'Baltimore, Maryland', 'SR key': 'baltimore', 'NCAA key': ''}
# Duplicated NCAA Key or not found in NCAA {'School': 'Boise State', 'City, State': 'Boise, Idaho', 'SR key': 'boise-state', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Bowling Green State', 'City, State': 'Bowling Green, Ohio', 'SR key': 'bowling-green-state', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Brigham Young', 'City, State': 'Provo, Utah', 'SR key': 'brigham-young', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Brigham Young College', 'City, State': 'Logan, Utah', 'SR key': 'brigham-young-college', 'NCAA key': ''}
# Duplicated NCAA Key or not found in NCAA {'School': 'Canterbury College', 'City, State': 'Danville, Indiana', 'SR key': 'central-normal-college', 'NCAA key': ''}
# Duplicated NCAA Key or not found in NCAA {'School': 'Central Arkansas', 'City, State': 'Conway, Arkansas', 'SR key': 'central-arkansas', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Central Connecticut State', 'City, State': 'New Britain, Connecticut', 'SR key': 'central-connecticut-state', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Central Florida', 'City, State': 'Orlando, Florida', 'SR key': 'central-florida', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Central Michigan', 'City, State': 'Mount Pleasant, Michigan', 'SR key': 'central-michigan', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Central Pennsylvania College Knights', 'City, State': 'Summerdale, Pennsylvania', 'SR key': 'central-pennsylvania-college', 'NCAA key': ''}
# Duplicated NCAA Key or not found in NCAA {'School': 'Charleston Southern', 'City, State': 'Charleston, South Carolina', 'SR key': 'charleston-southern', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Cheyenne Business College', 'City, State': 'Cheyenne, Wyoming', 'SR key': 'cheyenne-business-college', 'NCAA key': ''}
# Duplicated NCAA Key or not found in NCAA {'School': 'Chicago State', 'City, State': 'Chicago, Illinois', 'SR key': 'chicago-state', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Cleveland State', 'City, State': 'Cleveland, Ohio', 'SR key': 'cleveland-state', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Coastal Carolina', 'City, State': 'Conway, South Carolina', 'SR key': 'coastal-carolina', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Colorado State', 'City, State': 'Fort Collins, Colorado', 'SR key': 'colorado-state', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Concordia Seminary Preachers', 'City, State': 'St. Louis, Missouri', 'SR key': 'concordia-seminary', 'NCAA key': ''}
# Duplicated NCAA Key or not found in NCAA {'School': 'Coppin State', 'City, State': 'Baltimore, Maryland', 'SR key': 'coppin-state', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Cotner College', 'City, State': 'Lincoln, Nebraska', 'SR key': 'cotner-university', 'NCAA key': ''}
# Duplicated NCAA Key or not found in NCAA {'School': 'Cumberland', 'City, State': 'Lebanon, Tennessee', 'SR key': 'cumberland', 'NCAA key': ''}
# Duplicated NCAA Key or not found in NCAA {'School': 'Dakota Wesleyan Tigers', 'City, State': 'Mitchell, South Dakota', 'SR key': 'dakota-wesleyan', 'NCAA key': ''}
# Duplicated NCAA Key or not found in NCAA {'School': 'Delaware State', 'City, State': 'Dover, Delaware', 'SR key': 'delaware-state', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Detroit Mercy', 'City, State': 'Detroit, Michigan', 'SR key': 'detroit-mercy', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'East Tennessee State', 'City, State': 'Johnson City, Tennessee', 'SR key': 'east-tennessee-state', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Eastern Illinois', 'City, State': 'Charleston, Illinois', 'SR key': 'eastern-illinois', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Eastern Kentucky', 'City, State': 'Richmond, Kentucky', 'SR key': 'eastern-kentucky', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Eastern Michigan', 'City, State': 'Ypsilanti, Michigan', 'SR key': 'eastern-michigan', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Eastern Washington', 'City, State': 'Cheney, Washington', 'SR key': 'eastern-washington', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Ensign College', 'City, State': 'Salt Lake City, Utah', 'SR key': 'latter-day-saints-university', 'NCAA key': ''}
# Duplicated NCAA Key or not found in NCAA {'School': 'Florida Gulf Coast', 'City, State': 'Fort Myers, Florida', 'SR key': 'florida-gulf-coast', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Florida International', 'City, State': 'Miami, Florida', 'SR key': 'florida-international', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Florida State', 'City, State': 'Tallahassee, Florida', 'SR key': 'florida-state', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Georgia State', 'City, State': 'Atlanta, Georgia', 'SR key': 'georgia-state', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Haskell (KS) Fighting Indians', 'City, State': 'Lawrence, Kansas', 'SR key': 'haskell-indian-nations-institute', 'NCAA key': ''}
# Duplicated NCAA Key or not found in NCAA {'School': 'Idaho State', 'City, State': 'Pocatello, Idaho', 'SR key': 'idaho-state', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Illinois State', 'City, State': 'Normal, Illinois', 'SR key': 'illinois-state', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Illinois-Chicago', 'City, State': 'Chicago, Illinois', 'SR key': 'illinois-chicago', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Indiana State', 'City, State': 'Terre Haute, Indiana', 'SR key': 'indiana-state', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Iowa State', 'City, State': 'Ames, Iowa', 'SR key': 'iowa-state', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Jackson State', 'City, State': 'Jackson, Mississippi', 'SR key': 'jackson-state', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Jacksonville State', 'City, State': 'Jacksonville, Alabama', 'SR key': 'jacksonville-state', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Kansas State', 'City, State': 'Manhattan, Kansas', 'SR key': 'kansas-state', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Kennesaw State', 'City, State': 'Kennesaw, Georgia', 'SR key': 'kennesaw-state', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Kent State', 'City, State': 'Kent, Ohio', 'SR key': 'kent-state', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Lawrence Tech', 'City, State': 'Southfield, Michigan', 'SR key': 'lawrence-tech', 'NCAA key': ''}
# Duplicated NCAA Key or not found in NCAA {'School': 'Long Beach State', 'City, State': 'Long Beach, California', 'SR key': 'long-beach-state', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Louisiana State', 'City, State': 'Baton Rouge, Louisiana', 'SR key': 'louisiana-state', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Loyola (LA) Wolfpack', 'City, State': 'New Orleans, Louisiana', 'SR key': 'loyola-la', 'NCAA key': ''}
# Duplicated NCAA Key or not found in NCAA {'School': 'McNeese State', 'City, State': 'Lake Charles, Louisiana', 'SR key': 'mcneese-state', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Michigan State', 'City, State': 'East Lansing, Michigan', 'SR key': 'michigan-state', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Minnesota A&M Aggies', 'City, State': 'St. Paul, Minnesota', 'SR key': 'minnesota-am', 'NCAA key': ''}
# Duplicated NCAA Key or not found in NCAA {'School': 'Mississippi State', 'City, State': 'Mississippi State, Mississippi', 'SR key': 'mississippi-state', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Mississippi Valley State', 'City, State': 'Itta Bena, Mississippi', 'SR key': 'mississippi-valley-state', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Missouri State', 'City, State': 'Springfield, Missouri', 'SR key': 'missouri-state', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Morehead State', 'City, State': 'Morehead, Kentucky', 'SR key': 'morehead-state', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Morgan State', 'City, State': 'Baltimore, Maryland', 'SR key': 'morgan-state', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': "Mount St. Mary's", 'City, State': 'Emmitsburg, Maryland', 'SR key': 'mount-st-marys', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Murray State', 'City, State': 'Murray, Kentucky', 'SR key': 'murray-state', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'New Mexico State', 'City, State': 'Las Cruces, New Mexico', 'SR key': 'new-mexico-state', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Nicholls State', 'City, State': 'Thibodaux, Louisiana', 'SR key': 'nicholls-state', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Norfolk State', 'City, State': 'Norfolk, Virginia', 'SR key': 'norfolk-state', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'North Alabama', 'City, State': 'Florence, Alabama', 'SR key': 'north-alabama', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'North Dakota State', 'City, State': 'Fargo, North Dakota', 'SR key': 'north-dakota-state', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Northern Arizona', 'City, State': 'Flagstaff, Arizona', 'SR key': 'northern-arizona', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Northern Colorado', 'City, State': 'Greeley, Colorado', 'SR key': 'northern-colorado', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Northern Illinois', 'City, State': 'De Kalb, Illinois', 'SR key': 'northern-illinois', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Northern Kentucky', 'City, State': 'Highland Heights, Kentucky', 'SR key': 'northern-kentucky', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Northwestern State', 'City, State': 'Natchitoches, Louisiana', 'SR key': 'northwestern-state', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Oklahoma City Chiefs', 'City, State': 'Oklahoma City, Oklahoma', 'SR key': 'oklahoma-city', 'NCAA key': ''}
# Duplicated NCAA Key or not found in NCAA {'School': 'Oklahoma State', 'City, State': 'Stillwater, Oklahoma', 'SR key': 'oklahoma-state', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Pennsylvania', 'City, State': 'Philadelphia, Pennsylvania', 'SR key': 'pennsylvania', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Phillips Haymakers', 'City, State': 'Enid, Oklahoma', 'SR key': 'phillips', 'NCAA key': ''}
# Duplicated NCAA Key or not found in NCAA {'School': 'Portland State', 'City, State': 'Portland, Oregon', 'SR key': 'portland-state', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Sacramento State', 'City, State': 'Sacramento, California', 'SR key': 'sacramento-state', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'San Diego State', 'City, State': 'San Diego, California', 'SR key': 'san-diego-state', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'San Jose State', 'City, State': 'San Jose, California', 'SR key': 'san-jose-state', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Savage School of Physical Education', 'City, State': 'New York, New York', 'SR key': 'savage-school-of-physical-education', 'NCAA key': ''}
# Duplicated NCAA Key or not found in NCAA {'School': 'South Alabama', 'City, State': 'Mobile, Alabama', 'SR key': 'south-alabama', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'South Carolina State', 'City, State': 'Orangeburg, South Carolina', 'SR key': 'south-carolina-state', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'South Carolina Upstate', 'City, State': 'Spartanburg, South Carolina', 'SR key': 'south-carolina-upstate', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'South Dakota State', 'City, State': 'Brookings, South Dakota', 'SR key': 'south-dakota-state', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'South Florida', 'City, State': 'Tampa, Florida', 'SR key': 'south-florida', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Southeast Missouri State', 'City, State': 'Cape Girardeau, Missouri', 'SR key': 'southeast-missouri-state', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Southeastern Louisiana', 'City, State': 'Hammond, Louisiana', 'SR key': 'southeastern-louisiana', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Southern', 'City, State': 'Baton Rouge, Louisiana', 'SR key': 'southern', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Southern Illinois', 'City, State': 'Carbondale, Illinois', 'SR key': 'southern-illinois', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Southern Indiana', 'City, State': 'Evansville, Indiana', 'SR key': 'southern-indiana', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Southern Methodist', 'City, State': 'Dallas, Texas', 'SR key': 'southern-methodist', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Southwestern (KS) Moundbuilders', 'City, State': 'Winfield, Kansas', 'SR key': 'southwestern-ks', 'NCAA key': ''}
# Duplicated NCAA Key or not found in NCAA {'School': "St. John's College (OH)", 'City, State': 'Toledo, Ohio', 'SR key': 'st-johns-college-oh', 'NCAA key': ''}
# Duplicated NCAA Key or not found in NCAA {'School': 'Tarleton State', 'City, State': 'Stephenville, Texas', 'SR key': 'tarleton-state', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Tennessee State', 'City, State': 'Nashville, Tennessee', 'SR key': 'tennessee-state', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Texas State', 'City, State': 'San Marcos, Texas', 'SR key': 'texas-state', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'U.S. International Gulls', 'City, State': 'San Diego, California', 'SR key': 'alliant-international', 'NCAA key': ''}
# Duplicated NCAA Key or not found in NCAA {'School': 'Utah State', 'City, State': 'Logan, Utah', 'SR key': 'utah-state', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Virginia Commonwealth', 'City, State': 'Richmond, Virginia', 'SR key': 'virginia-commonwealth', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Washington (MO) Bears', 'City, State': 'St. Louis, Missouri', 'SR key': 'washington-mo', 'NCAA key': ''}
# Duplicated NCAA Key or not found in NCAA {'School': 'Washington State', 'City, State': 'Pullman, Washington', 'SR key': 'washington-state', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Weber State', 'City, State': 'Ogden, Utah', 'SR key': 'weber-state', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Western Carolina', 'City, State': 'Cullowhee, North Carolina', 'SR key': 'western-carolina', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Western Illinois', 'City, State': 'Macomb, Illinois', 'SR key': 'western-illinois', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Western Kentucky', 'City, State': 'Bowling Green, Kentucky', 'SR key': 'western-kentucky', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Western Michigan', 'City, State': 'Kalamazoo, Michigan', 'SR key': 'western-michigan', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Wichita State', 'City, State': 'Wichita, Kansas', 'SR key': 'wichita-state', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Wright State', 'City, State': 'Dayton, Ohio', 'SR key': 'wright-state', 'NCAA key': nan}
# Duplicated NCAA Key or not found in NCAA {'School': 'Youngstown State', 'City, State': 'Youngstown, Ohio', 'SR key': 'youngstown-state', 'NCAA key': nan}

# %% [markdown]
# ## Save data
# We will save the data in the `data` folder as `teams.csv`

# %%
path = os.path.abspath('../data/teams.csv')
df.to_csv(path, index=False)
